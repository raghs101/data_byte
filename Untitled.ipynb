# %%
import pandas as pd
import numpy as np
# read datasdet using pandas
df = pd.read_csv('test_dataset.csv')
df.head()
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0  3870      41      C          Placebo  22553   F       N          NaN  \
# 1  3462    1811      C  D-penicillamine  16223   F       N            Y
# 2  1632     954      C  D-penicillamine  27100   F       N            N
# 3   722    1969      D          Placebo  17039   F       N            Y
# 4  1000    2721      D  D-penicillamine  17738   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT
# 0       N     N        1.4        247.0     3.62     NaN       NaN  108.65  \
# 1       N     N        0.3        311.0     2.80    92.0    1748.1     NaN
# 2       N     N        0.4          NaN     3.56     NaN       NaN   43.52
# 3       N     N        1.2          NaN     3.16     NaN     617.1  113.76
# 4     NaN     N        3.2          NaN     2.36    89.0    1782.4     NaN
#
#    Tryglicerides  Platelets  Prothrombin
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (3200, 19)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0     3870      41      C          Placebo  22553   F       N          NaN  \
# 1     3462    1811      C  D-penicillamine  16223   F       N            Y
# 2     1632     954      C  D-penicillamine  27100   F       N            N
# 3      722    1969      D          Placebo  17039   F       N            Y
# 4     1000    2721      D  D-penicillamine  17738   F     NaN          NaN
# ...    ...     ...    ...              ...    ...  ..     ...          ...
# 3195  2601    4513      D          Placebo  18293   M     NaN            N
# 3196    53    3281      D              NaN  12149   F       N            N
# 3197   386    1933      D  D-penicillamine  17084   F     NaN            Y
# 3198   920    2350      D          Placebo  28650   M     NaN          NaN
# 3199  2047    2691      D  D-penicillamine  13765   F       N            N
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0     3870      41      C          Placebo  22553   F       N          NaN  \
# 1     3462    1811      C  D-penicillamine  16223   F       N            Y
# 2     1632     954      C  D-penicillamine  27100   F       N            N
# 3      722    1969      D          Placebo  17039   F       N            Y
# 4     1000    2721      D  D-penicillamine  17738   F     NaN          NaN
# ...    ...     ...    ...              ...    ...  ..     ...          ...
# 3195  2601    4513      D          Placebo  18293   M     NaN            N
# 3196    53    3281      D              NaN  12149   F       N            N
# 3197   386    1933      D  D-penicillamine  17084   F     NaN            Y
# 3198   920    2350      D          Placebo  28650   M     NaN          NaN
# 3199  2047    2691      D  D-penicillamine  13765   F       N            N
#
# ...

# %%
df.nunique()
# Out:
# ID               3200
# N_Days           1966
# Status              3
# Drug                2
# Age              2497
# Sex                 2
# Ascites             2
# Hepatomegaly        2
# Spiders             2
# Edema               3
# Bilirubin         183
# Cholesterol       354
# Albumin           248
# Copper            213
# Alk_Phos         1772
# SGOT             1674
# Tryglicerides     256
# Platelets         469
# Prothrombin        67
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                  0
# N_Days              0
# Status              0
# Drug              963
# Age                 0
# Sex                 0
# Ascites          1087
# Hepatomegaly     1102
# Spiders          1200
# Edema               0
# Bilirubin           0
# Cholesterol      1435
# Albumin             0
# Copper           1006
# Alk_Phos         1168
# SGOT              987
# Tryglicerides    1286
# Platelets         164
# Prothrombin        64
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('test_dataset.csv')  # Replace 'your_dataset.csv' with the actual file path

# Display the first few rows of the dataset
print(df.head())

# Get summary statistics
print(df.describe())

# Check the data types of each column
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())

# Data visualization
# Example plots: adjust as needed for your dataset
# Histogram of a numerical variable
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0  3870      41      C          Placebo  22553   F       N          NaN  \
# 1  3462    1811      C  D-penicillamine  16223   F       N            Y
# 2  1632     954      C  D-penicillamine  27100   F       N            N
# 3   722    1969      D          Placebo  17039   F       N            Y
# 4  1000    2721      D  D-penicillamine  17738   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT
# 0       N     N        1.4        247.0     3.62     NaN       NaN  108.65  \
# 1       N     N        0.3        311.0     2.80    92.0    1748.1     NaN
# 2       N     N        0.4          NaN     3.56     NaN       NaN   43.52
# 3       N     N        1.2          NaN     3.16     NaN     617.1  113.76
# 4     NaN     N        3.2          NaN     2.36    89.0    1782.4     NaN
#
#    Tryglicerides  Platelets  Prothrombin
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.shape()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('train_dataset.csv')  # Replace 'your_dataset.csv' with the actual file path

# Display the first few rows of the dataset
print(df.head())

# Get summary statistics
print(df.describe())

# Check the data types of each column
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())
#Data visualization
plt.hist(df['Stage'])
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Numerical Column')
plt.show()
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0  7135    1654     CL  D-penicillamine  19581   F       N            N  \
# 1  7326      41      C  D-penicillamine  22880   F     NaN            N
# 2  7254     297      D              NaN  27957   F       N            N
# 3  3135    1872      C  D-penicillamine  21111   F     NaN            Y
# 4  2483     939     CL  D-penicillamine  18061   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT
# 0       Y     N        0.3        279.0     2.96    84.0    1500.8   99.43  \
# 1     NaN     N        0.3          NaN     2.96     NaN    1835.4   26.35
# 2     NaN     N        0.3        328.0     2.64     4.0       NaN     NaN
# 3       Y     N        0.3        302.0     2.02    49.0       NaN   26.35
# 4     NaN     N        0.5        344.0     3.11    91.0       NaN  104.56
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('train_dataset.csv')  # Replace 'your_dataset.csv' with the actual file path

# Display the first few rows of the dataset
print(df.head())

# Get summary statistics
print(df.describe())

# Check the data types of each column
print(df.dtypes)
print(df.nunique)

# Check for missing values

print(df.isnull().sum())
#Data visualization
plt.hist(df['Prothrombin'])
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Numerical Column')
plt.show()
#code KNN
# Separate the features (X) and the target variable (y) for training set
X_train = df.drop(columns=['Stage']).values
y_train = df['Stage'].values



# K-Nearest Neighbors (KNN)
class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        y_pred = []
        for x in X:
            distances = np.linalg.norm(self.X_train - x, axis=1)  # Calculate Euclidean distances
            k_indices = np.argsort(distances)[:self.k]  # Get the indices of the k nearest neighbors
            k_nearest_labels = self.y_train[k_indices]  # Get the labels of the k nearest neighbors
            unique_labels, counts = np.unique(k_nearest_labels, return_counts=True)
            y_pred.append(unique_labels[np.argmax(counts)])  # Predict the class with the majority vote
        return np.array(y_pred)

# Train and evaluate the KNN model
k = 5  # Set the number of neighbors (K)
knn = KNN(k)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)

# Evaluation metrics
def accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

def precision(y_true, y_pred):
    tp = np.sum((y_true == 1) & (y_pred == 1))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    return tp / (tp + fp)

def recall(y_true, y_pred):
    tp = np.sum((y_true == 1) & (y_pred == 1))
    fn = np.sum((y_true == 1) & (y_pred == 0))
    return tp / (tp + fn)

def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec)

knn_accuracy = accuracy(y_test, knn_pred)
knn_precision = precision(y_test, knn_pred)
knn_recall = recall(y_test, knn_pred)
knn_f1 = f1_score(y_test, knn_pred)

# Compare the performance of the models
print("Model Performance:")
print("K-Nearest Neighbors (KNN): Accuracy = {:.4f}, Precision = {:.4f}, Recall = {:.4f}, F1-score = {:.4f}".format(
    knn_accuracy, knn_precision, knn_recall, knn_f1))
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly
# 0  7135    1654     CL  D-penicillamine  19581   F       N            N  \
# 1  7326      41      C  D-penicillamine  22880   F     NaN            N
# 2  7254     297      D              NaN  27957   F       N            N
# 3  3135    1872      C  D-penicillamine  21111   F     NaN            Y
# 4  2483     939     CL  D-penicillamine  18061   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT
# 0       Y     N        0.3        279.0     2.96    84.0    1500.8   99.43  \
# 1     NaN     N        0.3          NaN     2.96     NaN    1835.4   26.35
# 2     NaN     N        0.3        328.0     2.64     4.0       NaN     NaN
# 3       Y     N        0.3        302.0     2.02    49.0       NaN   26.35
# 4     NaN     N        0.5        344.0     3.11    91.0       NaN  104.56
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...
